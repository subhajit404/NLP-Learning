# %%
import pandas as pd

# %%
df =pd.read_csv("IMDB Dataset.csv")

# %%
import re

# %%
def removal_html_tag(text):
    pattern =re.compile('<.*?>')
    return pattern.sub(r'',text)

# %%
text = '<p>This is the second paragraph, separated by a line.</p>'

print(removal_html_tag(text))
# Out:
# This is the second paragraph, separated by a line.

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['review']=df['review'].apply(removal_html_tag)

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. The filming tec...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
import string
# translator = str.maketrans('', '', string.punctuation)
marks = string.punctuation

# %%
marks
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punc(text):
    for char in marks:
        text= text.replace(char,'')
    return text

# %%
df['review']=df['review'].apply(remove_punc)

# %%
def remove_punc1(text):
    return text.translate(str.maketrans('','',marks))

# %%
df['review']=df['review'].apply(remove_punc1)

# %%
df['review']
# Out:
# 0        One of the other reviewers has mentioned that ...
# 1        A wonderful little production The filming tech...
# 2        I thought this was a wonderful way to spend ti...
# 3        Basically theres a family where a little boy J...
# 4        Petter Matteis Love in the Time of Money is a ...
#                                ...
# 49995    I thought this movie did a down right good job...
# 49996    Bad plot bad dialogue bad acting idiotic direc...
# 49997    I am a Catholic taught in parochial elementary...
# 49998    Im going to have to disagree with the previous...
# 49999    No one expects the Star Trek movies to be high...
# Name: review, Length: 50000, dtype: str

# %%
# !pip install autocorrect
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install spellchecker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install  textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from textblob import TextBlob

# %%
incorrect_text= "Yesterday, the goverment official recieved an urgent mesage from his collaege regarding the accomodation for the upcoming symposium, but teh system ws unable to process the requst due to a technical glich."

TextBlb = TextBlob(incorrect_text)
corrected_text=TextBlb.correct().string
print(TextBlb)
print(corrected_text)
# Out:
# Yesterday, the goverment official recieved an urgent mesage from his collaege regarding the accomodation for the upcoming symposium, but teh system ws unable to process the requst due to a technical glich.
# Yesterday, the government official received an urgent message from his college regarding the accommodation for the coming symposium, but the system was unable to process the request due to a technical which.

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production The filming tech...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically theres a family where a little boy J...  negative
# 4      Petter Matteis Love in the Time of Money is a ...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  Im going to have to disagree with the previous...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\subha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
text ='I am going to the market because I need to buy some vegetables and fruits.'

def remove_stopwords(text):
    new_text =[]
    for words in text.split():
        if words in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(words)
    x= new_text[:]
    new_text.clear()
    return " ".join(x)

remove_stopwords(text)
# Out:
# 'I  going   market  I need  buy  vegetables  fruits.'

# %%
# !pip install demoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install emoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import emoji

text = "Good morning! ☀️ Have a nice day! 🌸😊"

# Replace emojis with an empty string
cleaned_text = emoji.replace_emoji(text, replace='')

print(cleaned_text)
# Output: Good morning!  Have a nice day!
# Out:
# Good morning!  Have a nice day!

# %%
import demoji

text = "Python is fun! 🐍🔥 Let's code! 💻🎉"

# Replace all emojis with an empty string
cleaned_text = demoji.replace(text, "")

print(cleaned_text)
# Output: Python is fun!  Let's code!
# Out:
# Python is fun!  Let's code!

# %%
print(emoji.demojize(text))
# Out:
# Python is fun! :snake::fire: Let's code! :laptop::party_popper:

# %% [markdown]
# # **Tokenization**

# %%
text ='Yesterday, the government official received. an urgent message from. his college regarding the accommodation for the coming symposium,. but the system was unable to process the request due to a technical which.'
text.split('.')
# Out:
# ['Yesterday, the government official received',
#  ' an urgent message from',
#  ' his college regarding the accommodation for the coming symposium,',
#  ' but the system was unable to process the request due to a technical which',
#  '']

# %%
import re
import warnings
warnings.filterwarnings('ignore')

# %%
text = 'Yesterday, the government official received an urgent message from his college regarding the accommodation for the coming symposium, but the system was unable to process the request due to a technical which.'
tokens = re.findall("[\w]+",text)

# %%
tokens
# Out:
# ['Yesterday',
#  'the',
#  'government',
#  'official',
#  'received',
#  'an',
#  'urgent',
#  'message',
#  'from',
#  'his',
#  'college',
#  'regarding',
#  'the',
#  'accommodation',
#  'for',
#  'the',
#  'coming',
#  'symposium',
#  'but',
#  'the',
#  'system',
#  'was',
#  'unable',
#  'to',
#  'process',
#  'the',
#  'request',
#  'due',
#  'to',
#  'a',
#  'technical',
#  'which']

# %%
from nltk import word_tokenize,sent_tokenize

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\subha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sent1 = 'Yesterday, the government official received an urgent message from his college regarding the accommodation for the coming symposium, but the system was unable to process the request due to a technical which.'
word_tokenize(sent1)
# Out:
# ['Yesterday',
#  ',',
#  'the',
#  'government',
#  'official',
#  'received',
#  'an',
#  'urgent',
#  'message',
#  'from',
#  'his',
#  'college',
#  'regarding',
#  'the',
#  'accommodation',
#  'for',
#  'the',
#  'coming',
#  'symposium',
#  ',',
#  'but',
#  'the',
#  'system',
#  'was',
#  'unable',
#  'to',
#  'process',
#  'the',
#  'request',
#  'due',
#  'to',
#  'a',
#  'technical',
#  'which',
#  '.']

# %%
sent1 = 'Yesterday, the government. official received an urgent message. from his college regarding. the accommodation for the coming symposium, but the system was unable to process the request due to a technical which.'
sent_tokenize(sent1)
# Out:
# ['Yesterday, the government.',
#  'official received an urgent message.',
#  'from his college regarding.',
#  'the accommodation for the coming symposium, but the system was unable to process the request due to a technical which.']

# %%
! pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 4.1 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.6/12.8 MB 4.6 MB/s eta 0:00:03
#      --------- ------------------------------ 2.9/12.8 MB 5.5 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 5.8 MB/s eta 0:00:02
#      ------------------ --------------------- 6.0/12.8 MB 6.5 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.8 MB 6.6 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 6.4 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 7.8 MB/s  0:00:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# %%
sp = spacy.load('en_core_web_sm')

# %%
doc1 = sp(sent1)

# %%
print(doc1)
# Out:
# Yesterday, the government. official received an urgent message. from his college regarding. the accommodation for the coming symposium, but the system was unable to process the request due to a technical which.

# %%
for token in doc1:
    print(token)
# Out:
# Yesterday
# ,
# the
# government
# .
# official
# received
# an
# urgent
# message
# .
# from
# his
# college
# regarding
# .
# the
# accommodation
# for
# the
# coming
# symposium
# ,
# but
# the
# system
# was
# unable
# to
# process
# the
# request
# due
# to
# a
# technical
# which
# .
