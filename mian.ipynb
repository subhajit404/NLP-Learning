# %%
import numpy as np
import pandas as pd
import requests

# %%
result = requests.get('https://www.omdbapi.com/?apikey=11b9ae7f&s=Avengers')

# %%
result.json()
# Out:
# {'Search': [{'Title': 'The Avengers',
#    'Year': '2012',
#    'imdbID': 'tt0848228',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BNGE0YTVjNzUtNzJjOS00NGNlLTgxMzctZTY4YTE1Y2Y1ZTU4XkEyXkFqcGc@._V1_QL75_UX380_CR0,0,380,562_.jpg'},
#   {'Title': 'Avengers: Endgame',
#    'Year': '2019',
#    'imdbID': 'tt4154796',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMWEyNDM2ZmQtMmFkNi00MTQ1LTk1MjItMzdlZGJlYmIyYzZlXkEyXkFqcGc@._V1_QL75_UX380_CR0,0,380,562_.jpg'},
#   {'Title': 'Avengers: Infinity War',
#    'Year': '2018',
#    'imdbID': 'tt4154756',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_QL75_UX380_CR0,0,380,562_.jpg'},
#   {'Title': 'Avengers: Age of Ultron',
#    'Year': '2015',
#    'imdbID': 'tt2395427',
#    'Type': 'movie',
# ...

# %%
df = pd.DataFrame(result.json())

# %%
df
# Out:
#                                               Search totalResults Response
# 0  {'Title': 'The Avengers', 'Year': '2012', 'imd...          175     True
# 1  {'Title': 'Avengers: Endgame', 'Year': '2019',...          175     True
# 2  {'Title': 'Avengers: Infinity War', 'Year': '2...          175     True
# 3  {'Title': 'Avengers: Age of Ultron', 'Year': '...          175     True
# 4  {'Title': 'The Avengers', 'Year': '1998', 'imd...          175     True
# 5  {'Title': 'The Avengers: Earth's Mightiest Her...          175     True
# 6  {'Title': 'Ultimate Avengers: The Movie', 'Yea...          175     True
# 7  {'Title': 'The Avengers', 'Year': '1961–1969',...          175     True
# 8  {'Title': 'Avengers Assemble', 'Year': '2012–2...          175     True
# 9  {'Title': 'Ultimate Avengers II', 'Year': '200...          175     True
